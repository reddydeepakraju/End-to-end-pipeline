# %% [markdown]
# <a href="https://colab.research.google.com/github/reddydeepakraju/End-to-end-pipeline/blob/main/data_pipeline.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
https://www.kaggle.com/datasets/lakshmi25npathi/imdb-dataset-of-50k-movie-reviews?resource=download

# %%
import pandas as pd

# %%
# !pwd
# Out:
# /content

# %%
data_path="/content/IMDB Dataset.csv"

# %%
df=pd.read_csv(data_path)

# %%
df.shape
